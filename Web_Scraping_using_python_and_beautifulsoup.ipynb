# %% [markdown]
# # **Web scraping using beautiful soup**
#
# This notebook includes data scraping, which takes a website URL as an input and extracts the information listed below as an output from that webpage.
#
#
# 1.   Specific HTML tags along with titles and meta description
# 2.   Extract specific tags, heading tags from h1-h6 along with titles and meta description
# 3. Extracting ALT tags
# 4. For counting words inside a web page
# 5. Inspection of broken links inside a webpage
# 6. Extracting the source code of the webpage in google colab
# 7. Extracting all URLs from a website without duplication
# 8. Measuring the forntend and backend performance of website

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.14.1)

# %% [markdown]
# **1. For scraping specific HTML tags along with titles and meta description**

# %%
#Importing libraries
from bs4 import BeautifulSoup
import urllib
from urllib import request
import urllib.request as ur

# %%
# Getting input for webiste from user
urlinput = input("Enter url :")
print(" This is the website link that you entered", urlinput)

# For extracting specific tags from webpage
def getTags(tag):
  s = ur.urlopen(urlinput)
  soup = BeautifulSoup(s.read())
  return soup.findAll(tag)

# For extracting specific title & meta description from webpage
def titleandmetaTags():
    s = ur.urlopen(urlinput)
    soup = BeautifulSoup(s.read())
    #----- Extracting Title from website ------#
    title = soup.title.string
    print ('Website Title is :', title)
    #-----  Extracting Meta description from website ------#
    meta_description = soup.find_all('meta')
    for tag in meta_description:
        if 'name' in tag.attrs.keys() and tag.attrs['name'].strip().lower() in ['description', 'keywords']:
            #print ('NAME    :',tag.attrs['name'].lower())
            print ('CONTENT :',tag.attrs['content'])

#------------- Main ---------------#
if __name__ == '__main__':
  titleandmetaTags()
  tags = getTags('h1')
  for tag in tags:
     print(tag) # display tags
     print(tag.contents) # display contents of the tags
# Out:
# Enter url :https://ulab.edu.bd/
#  This is the website link that you entered https://ulab.edu.bd/
# Website Title is : University of Liberal Arts Bangladesh |
# <h1 class="hide">University of Liberal Arts Bangladesh </h1>
# ['University of Liberal Arts Bangladesh ']
# /tmp/ipython-input-20-2427648557.py:9: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   return soup.findAll(tag)

# %% [markdown]
# **2. For extracting specific tags, all heading tags from h1-h6 along with titles and meta description**

# %%
# Importing libraries
from bs4 import BeautifulSoup
import urllib
from urllib import request
import urllib.request as ur

# %%
# Getting input for webiste from user
url_input = input("Enter url :")
print(" This is the website link that you entered", url_input)


# For extracting specific tags from webpage
def getTags(tag):
  s = ur.urlopen(url_input)
  soup = BeautifulSoup(s.read())
  return soup.findAll(tag)

# For extracting all h1-h6 heading tags from webpage
def headingTags(headingtags):
  h = ur.urlopen(url_input)
  soup = BeautifulSoup(h.read())
  print("List of headings from headingtags function h1, h2, h3, h4, h5, h6 :")
  for heading in soup.find_all(["h1", "h2", "h3", "h4", "h5", "h6"]):
    print(heading.name + ' ' + heading.text.strip())

# For extracting specific title & meta description from webpage
def titleandmetaTags():
    s = ur.urlopen(urlinput)
    soup = BeautifulSoup(s.read())
    #----- Extracting Title from website ------#
    title = soup.title.string
    print ('Website Title is :', title)
    #-----  Extracting Meta description from website ------#
    meta_description = soup.find_all('meta')
    for tag in meta_description:
        if 'name' in tag.attrs.keys() and tag.attrs['name'].strip().lower() in ['description', 'keywords']:
            #print ('NAME    :',tag.attrs['name'].lower())
            print ('CONTENT :',tag.attrs['content'])



#------------- Main ---------------#
if __name__ == '__main__':
  titleandmetaTags()
  tags = getTags('p')
  headtags = headingTags('h1')
  for tag in tags:
     print(" Here are the tags from getTags function:", tag.contents)
# Out:
# Enter url :https://ulab.edu.bd/
#  This is the website link that you entered https://ulab.edu.bd/
# Website Title is : University of Liberal Arts Bangladesh |
# /tmp/ipython-input-4-3414949798.py:10: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   return soup.findAll(tag)
# List of headings from headingtags function h1, h2, h3, h4, h5, h6 :
# h1 University of Liberal Arts Bangladesh
# h2 Schools
# h3 Notice Board
# h3 Events
# h3 Student Projects
# h3 ULAB is ranked second among all private universities in research spending. (UGC Report 2019)
# h3 Featured ULABians
# h3 Extracurricular Activities
#  Here are the tags from getTags function: ['688 Beribadh Road', <br/>, 'Mohammadpur', <br/>, 'Dhaka - 1207, Bangladesh']

# %% [markdown]
# **3. For extracting ALT tags (Image Alter tags)**

# %%
import urllib.request as ur
from bs4 import BeautifulSoup

url_input = input("Enter url :")
print("The website link that you entered is:", url_input)

def alt_tag():
  url =  ur.urlopen(url_input)
  htmlSource = url.read()
  url.close()
  soup = BeautifulSoup(htmlSource)
  print('\n The alt tag along with the text in the web page')
  return soup


#------------- Main ---------------#
if __name__ == '__main__':
  soup_obj = alt_tag()
  print(soup_obj.find_all('img',alt= True))
# Out:
# Enter url :https://ulab.edu.bd/
# The website link that you entered is: https://ulab.edu.bd/
#
#  The alt tag along with the text in the web page
# [<img alt="sidebar-logo" src="/sites/all/themes/sloth/images/ulab-logo-white.svg"/>, <img alt="" class="image-style-none" src="https://ulab.edu.bd/sites/default/files/menuimage/my-logo.png"/>, <img alt="University of Liberal Arts Bangladesh" class="logo" src="https://ulab.edu.bd/sites/all/themes/sloth/logo.svg"/>, <img alt="University of Liberal Arts Bangladesh" class="logo" src="https://ulab.edu.bd/sites/all/themes/sloth/logo.svg"/>, <img alt="" class="image-style-image-300x300" src="https://ulab.edu.bd/sites/default/files/styles/image_300x300/public/event-image/2025/07/01/Yoga-Day-ULAB-2025-500.jpg?itok=E9OoF5GT"/>, <img alt="" class="image-style-image-300x300" src="https://ulab.edu.bd/sites/default/files/styles/image_300x300/public/event-image/2025/06/25/Rabindra-Nazrul-Anniversary-2025-500.jpg?itok=zZXYuKr7"/>, <img alt="" class="image-style-image-300x300" src="https://ulab.edu.bd/sites/default/files/styles/image_300x300/public/uploads/2025/06/18/Bangla%20vasa.jpg?itok=RuAA_fPh"/>, <img alt="Prof. Imran Rahman" class="enlarge ulab-lazyload" data-src="https://ulab.edu.bd/sites/default/files/styles/brochure_square/public/ulabians/2021/07/04/Imran%20Rahman.jpg?itok=icgoZSuS"/>, <img alt="Prof. Jude W.R. Genilo, PhD" class="enlarge ulab-lazyload" data-src="https://ulab.edu.bd/sites/default/files/styles/brochure_square/public/ulabians/2021/07/04/Prof.%20Jude.jpg?itok=YtfYcKtw"/>, <img alt="Samiya A Selim, PhD" class="enlarge ulab-lazyload" data-src="https://ulab.edu.bd/sites/default/files/styles/brochure_square/public/message_from/2021/08/19/Samiya-Selim_.jpg?itok=5YFZsJSe"/>, <img alt="Prof. Shahnaj Husne Jahan, PhD" class="enlarge ulab-lazyload" data-src="https://ulab.edu.bd/sites/default/files/styles/brochure_square/public/images/faculty/Shahnaj.jpg?itok=Rl75gU0F"/>, <img alt="Prof. Kaiser Hamidul Haq, PhD" class="enlarge ulab-lazyload" data-src="https://ulab.edu.bd/sites/default/files/styles/brochure_square/public/ulabians/2021/07/04/Kaiser%20sir.jpg?itok=ToAurtjb"/>, <img alt="Prof. Shamsad Mortuza, PhD" class="enlarge ulab-lazyload" data-src="https://ulab.edu.bd/sites/default/files/styles/brochure_square/public/images/faculty/PVC%20Sir.jpg?itok=WBT4KjVd"/>, <img alt="Prof. Abdul Mannan" class="enlarge ulab-lazyload" data-src="https://ulab.edu.bd/sites/default/files/styles/brochure_square/public/images/faculty/Abdul%20Mannan.jpg?itok=jZfbVGrI"/>, <img alt="Arifa Ghani Rahman" class="enlarge ulab-lazyload" data-src="https://ulab.edu.bd/sites/default/files/styles/brochure_square/public/images/faculty/ArifaMam_300x300.jpg?itok=p-iQodMy"/>, <img alt="Prof. Din M. Sumon Rahman, PhD" class="enlarge ulab-lazyload" data-src="https://ulab.edu.bd/sites/default/files/styles/brochure_square/public/images/faculty/MSJ-Dean-Sumon-Sir-300.jpg?itok=aJ41xZZZ"/>, <img alt="" class="image-style-image-300x300" src="https://ulab.edu.bd/sites/default/files/styles/image_300x300/public/news-image/2025/07/10/Shutterbugs-52.jpg?itok=fVtfq78o&amp;c=7d690f04f24a1156b3d9d3982d3bbc68"/>, <img alt="" class="image-style-image-300x300" src="https://ulab.edu.bd/sites/default/files/styles/image_300x300/public/news-image/2025/06/29/NAJ07990%20%281%29.jpg?itok=r3KjePTR&amp;c=80be0918c1623b09e00a34803ab74e91"/>, <img alt="" class="image-style-image-300x300" src="https://ulab.edu.bd/sites/default/files/styles/image_300x300/public/news-image/2025/06/20/FOAP-Summer25%20%286%29.jpg?itok=GTBXz3j8&amp;c=c11888ec04c3837413968a7ab11e05f8"/>, <img alt="" class="image-style-image-300x300" src="https://ulab.edu.bd/sites/default/files/styles/image_300x300/public/news-image/2025/06/03/Distinguished-Webinar-Poster.jpg?itok=ktSKSiTq&amp;c=827928c88ec283a8142a357d1f8be0f7"/>, <img alt="" class="image-style-image-300x300" src="https://ulab.edu.bd/sites/default/files/styles/image_300x300/public/news-image/2025/06/04/ULAB-Signs-MOU-with-Venturas-Ltd-300.jpg?itok=yzXJQTaG&amp;c=7d690f04f24a1156b3d9d3982d3bbc68"/>, <img alt="" class="image-style-image-300x300" src="https://ulab.edu ...

# %% [markdown]
# **4. For counting words inside a web page**

# %%
import requests
from bs4 import BeautifulSoup
from collections import Counter
from string import punctuation

# Getting content from web page
r = requests.get("https://ulab.edu.bd/")
soup = BeautifulSoup(r.content)

# For getting words within paragrphs
text_paragraph = (''.join(s.findAll(text=True))for s in soup.findAll('p'))
count_paragraph = Counter((x.rstrip(punctuation).lower() for y in text_paragraph for x in y.split()))

# For getting words inside div tags
text_div = (''.join(s.findAll(text=True))for s in soup.findAll('div'))
count_div = Counter((x.rstrip(punctuation).lower() for y in text_div for x in y.split()))

# Adding two counters for getting a list with words count (from most to less common)
total = count_div + count_paragraph
list_most_common_words = total.most_common()
# Out:
# /tmp/ipython-input-24-1163802322.py:11: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   text_paragraph = (''.join(s.findAll(text=True))for s in soup.findAll('p'))
# /tmp/ipython-input-24-1163802322.py:15: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   text_div = (''.join(s.findAll(text=True))for s in soup.findAll('div'))

# %%
# Total words inside a webpage
len(total)
# Out:
# 1108

# %%
# List of common words
list_most_common_words
# Out:
# [('and', 1409),
#  ('of', 1378),
#  ('the', 1338),
#  ('to', 926),
#  ('ulab', 711),
#  ('a', 632),
#  ('club', 499),
#  ('', 445),
#  ('in', 438),
#  ('is', 413),
#  ('for', 348),
#  ('explore', 276),
#  ('with', 262),
#  ('more', 254),
#  ('center', 254),
#  ('2025', 250),
#  ('on', 206),
#  ('students', 204),
#  ('at', 202),
#  ('review', 192),
#  ('tabs-panel', 184),
#  ('as', 182),
#  ('research', 157),
#  ('media', 148),
#  ('university', 147),
#  ('society', 144),
#  ('visit', 142),
#  ('faculty', 133),
#  ('social', 132),
#  ('language', 126),
#  ('bangladesh', 126),
#  ('eee', 115),
#  ('through', 114),
#  ('studies', 113),
#  ('their', 112),
#  ('development', 109),
#  ('skills', 108),
#  ('english', 101),
#  ('summer', 100),
#  ('arts', 97),
#  ('an', 96),
#  ('our', 96),
#  ('will', 88),
#  ('project', 88),
#  ('by', 86),
#  ('spring', 85),
#  ('art', 85),
#  ('field', 85),
#  ('sports', 85),
#  ('computer', 84),
#  ('prof', 84),
#  ('participation', 84),
#  ('provide', 84),
#  ('all', 82),
#  ('student', 76),
#  ('fall', 76),
#  ('business', 75),
#  ('liberal', 74),
#  ('dedicated', 72),
#  ('learning', 72),
#  ('rahman', 72),
#  ('phd', 72),
#  ('be', 72),
#  ('education', 70),
#  ('school', 68),
#  ('international', 65),
#  ('ulabian', 65),
#  ('its', 63),
#  ('has', 62),
#  ('get', 61),
#  ('sustainable', 61),
#  ('film', 61),
#  ('programs', 60),
#  ('poster', 60),
#  ('integration', 60),
#  ('promote', 60),
#  ('them', 60),
#  ('can', 60),
#  ('knowledge', 60),
#  ('also', 60),
#  ('develop', 60),
#  ('different', 60),
#  ('activities', 58),
#  ('department', 57),
#  ('jul', 56),
#  ('july', 56),
#  ('from', 56),
#  ('2023', 56),
#  ('presentation', 56),
#  ('dhaka', 56),
#  ('haq', 56),
#  ('but', 56),
#  ('electronics', 55),
#  ('organized', 54),
#  ('your', 52),
#  ('only', 52),
#  ('opportunities', 52),
#  ('up', 52),
#  ('other', 52),
#  ('personal', 52),
#  ('literary', 50),
#  ('indoor', 49),
#  ('digital', 49),
#  ('marketing', 49),
#  ('critical', 48),
#  ('teaching', 48),
#  ('improve', 48),
#  ('world', 48),
#  ('experience', 48),
#  ('communication', 48),
#  ('power', 48),
#  ('scholarship', 48),
#  ('2024', 48),
#  ('stories', 48),
#  ('platform', 48),
#  ('it', 48),
#  ('members', 48),
#  ('mission', 48),
#  ('we', 48),
#  ('learn', 48),
#  ('mass', 48),
#  ('undergraduate', 47),
#  ('among', 47),
#  ('–', 46),
#  ('exhibition', 46),
#  ('msj', 45),
#  ('events', 44),
#  ('curriculum', 44),
#  ('political', 44),
#  ('lives', 44),
#  ('not', 44),
#  ('poetry', 43),
#  ('02', 42),
#  ('june', 42),
#  ('showcasing', 42),
#  ('view', 42),
#  ('bangla', 41),
#  ('engineering', 41),
#  ('are', 41),
#  ('history', 41),
#  ('translation', 40),
#  ('vice', 40),
#  ('kaiser', 40),
#  ('sciences', 39),
#  ('go', 39),
#  ('https://platform.sharethis.com/apps', 39),
#  ('customize', 39),
#  ('tools', 39),
#  ('study', 38),
#  ('academic', 38),
#  ('life', 38),
#  ('(ulab', 38),
#  ('this', 38),
#  ('jahan', 38),
#  ('aims', 36),
#  ('various', 36),
#  ('archaeological', 36),
#  ('understanding', 36),
#  ('challenges', 36),
#  ('use', 36),
#  ('bangladeshi', 36),
#  ('population', 36),
#  ('environment', 36),
#  ('head', 36),
#  ('educator', 36),
#  ('communities', 36),
#  ('which', 36),
#  ('about', 36),
#  ('workshops', 36),
#  ('or', 36),
#  ('better', 36),
#  ('aim', 36),
#  ('interest', 36),
#  ('new', 36),
#  ('culture', 36),
#  ('vision', 36),
#  ('that', 36),
#  ('awareness', 36),
#  ('cultural', 36),
#  ('theater', 36),
#  ('humanities', 35),
#  ('information', 34),
#  ('projects', 34),
#  ('ulabians', 34),
#  ('career', 32),
#  ('station', 32),
#  ('hasan', 32),
#  ('conference', 32),
#  ('seminar', 32),
#  ('list', 32),
#  ('novel', 32),
#  ('syed', 32),
#  ('novellas', 32),
#  ('twelve', 32),
#  ('blood', 32),
#  ('ও', 31),
#  ('national', 31),
#  ('graduate', 31),
#  ('she', 30),
#  ('ইউলাবে', 30),
#  ('রবীন্দ্র-নজরুল', 30),
#  ('জয়ন্তী', 30),
#  ('science', 28),
#  ('sunday', 28),
#  ('midterm', 28),
#  ('exam', 28),
#  ('start', 28),
#  ('শুদ্ধ', 28),
#  ('titled', 28),
#  ('wordsworth', 28),
#  ('country’s', 28),
#  ('ces', 28),
#  ('greater', 28),
#  ('distinguished', 28),
#  ('poet', 28),
#  ('table', 28),
#  ('women', 28),
#  ('building', 28),
#  ('un', 28),
#  ('dialogue', 28),
#  ('quality', 27),
#  ('deh', 27),
#  ('2022', 27),
#  ('browse', 26),
#  ('competition', 26),
#  ('dept', 26),
#  ('2020', 26),
#  ('critic', 26),
#  ('cls', 25),
#  ('2019', 25),
#  ('photography', 25),
#  ('games', 25),
#  ('nutrition', 25),
#  ('rotaract', 25),
#  ('model', 25),
#  ('united', 25),
#  ('nations', 25),
#  ('1971', 25),
#  ('kaleidoscope', 25),
#  ('apply', 24),
#  ('office', 24),
#  ('campus', 24),
#  ('advanced', 24),
#  ('theory', 24),
#  ('aspects', 24),
#  ('seeks', 24),
#  ('qualitative', 24),
#  ('objective', 24),
#  ('thinking', 24),
#  ('design', 24),
#  ('enterprise', 24),
#  ('bangladesh’s', 24),
#  ('excellence', 24),
#  ('developing', 24),
#  ('practices', 24),
#  ('south', 24),
#  ('collaboration', 24),
#  ('csd', 24),
#  ('exchange', 24),
#  ('health', 24),
#  ('imran', 24),
#  ('chancellor', 24),
#  ('years', 24),
#  ('jude', 24),
#  ('w.r', 24),
#  ('genilo', 24),
#  ('highly', 24),
#  ('administrator', 24),
#  ('expert', 24),
#  ('samiya', 24),
#  ('selim', 24),
#  ('director', 24),
#  ('internationally', 24),
#  ('change', 24),
#  ('shahnaj', 24),
#  ('husne', 24),
#  ('dean', 24),
#  ('translator', 24),
#  ('shamsad', 24),
#  ('mortuza', 24),
#  ('advisor', 24),
#  ('columnist', 24),
#  ('editor', 24),
#  ('abdul', 24),
#  ('mannan', 24),
#  ('arifa', 24),
#  ('din', 24),
#  ('m', 24),
#  ('sumon', 24),
#  ('news', 24),
#  ('together', 24),
#  ('engage', 24),
#  ('themselves', 24),
#  ('help', 24),
#  ('arrange', 24),
#  ('creative', 24),
#  ('during', 24),
#  ('out', 24),
#  ('well', 24),
#  ('where', 24),
#  ('interested', 24),
#  ('each', 24),
#  ('leadership', 24),
#  ('enhance', 24),
#  ('making', 24),
#  ('you', 24),
#  ('basic', 24),
#  ('come', 24),
#  ('cricket', 24),
#  ('football', 24),
#  ('may', 24),
#  ('field-based', 24),
#  ('formed', 24),
#  ('who', 24),
#  ('active', 24),
#  ('provides', 24),
#  ('understand', 24),
#  ('opportunity', 24),
#  ('types', 24),
#  ('foster', 24),
#  ('unique', 24),
#  ('organization', 24),
#  ('become', 24),
#  ('young', 24),
#  ('physical', 24),
#  ('seminars', 24),
#  ('between', 24),
#  ('encourage', 24),
#  ('notice', 23),
#  ('private', 23),
#  ('universities', 23),
#  ('offers', 22),
#  ('general', 22),
#  ('program', 22),
#  ('chancellor’s', 19),
#  ('schools', 19),
#  ('prospectus', 17),
#  ('library', 16),
#  ('(ugc', 16),
#  ('“the', 16),
#  ('ray', 16),
#  ('hope', 16),
#  ('you”', 16),
#  ('ulab’s', 16),
#  ('forum', 16),
#  ('unpacks', 16),
#  ('aftermath', 16),
#  ('revolution', 16),
#  ('holds', 16),
#  ('orientation', 16),
#  ('webinar', 16),
#  ('next-gen', 16),
#  ('energy', 16),
#  ('efficient', 16),
#  ('3d', 16),
#  ('smart', 16),
#  ('materials', 16),
#  ('signs', 16),
#  ('mou', 16),
#  ('venturas', 16),
#  ('ltd', 16),
#  ('boost', 16),
#  ('japan', 16),
#  ('tour', 16),
#  ('raozan', 16),
#  ('thermal', 16),
#  ('kaptai', 16),
#  ('hydro', 16),
#  ('md', 16),
#  ('sajid', 16),
#  ('selected', 16),
#  ('reviewer', 16),
#  ('artificial', 16),
#  ('intelligence', 16),
#  ('data', 16),
#  ('applications', 16),
#  ('(acdsa', 16),
#  ('wraps', 16),
#  ('shilpakala', 16),
#  ('academy', 16),
#  ('focus', 16),
#  ('network', 16),
#  ('propaganda', 16),
#  ('workshop', 16),
#  ('march', 16),
#  ('heritage', 16),
#  ('preservation', 16),
#  ('april', 16),
#  ("dean's", 16),
#  ('honors', 16),
#  ('publishes', 16),
#  ('ieee', 16),
#  ('paper', 16),
#  ('solar', 16),
#  ('pv', 16),
#  ('system', 16),
#  ('stadium', 16),
#  ('round', 16),
#  ('discussion', 16),
#  ('"the', 16),
#  ('uprising', 16),
#  ('named', 16),
#  ('quantum', 16),
#  ('spin', 16),
#  ('hall', 16),
#  ('insulators', 16),
#  ('best', 16),
#  ('capstone', 16),
#  ('awards', 16),
#  ('tribune', 16),
#  ('host', 16),
#  ('‘national', 16),
#  ('civil', 16),
#  ('dialog', 16),
#  ('reforming', 16),
#  ('bangladesh’', 16),
#  ('modern', 16),
#  ('portrayed', 16),
#  ("'a", 16),
#  ('strange', 16),
#  ('coincidence', 16),
#  ('‘bangladesh', 16),
#  ('stories’', 16),
#  ('gives', 16),
#  ('inside', 16),
#  ('look', 16),
#  ('garment', 16),
#  ('industry', 16),
#  ('book', 16),
#  ("''the", 16),
#  ("devil's", 16),
#  ('thumbprint', 16),
#  ('upon', 16),
#  ('rereading', 16),
#  ('‘forty', 16),
#  ('steps’', 16),
#  ('interleaving', 16),
#  ('memory', 16),
#  ('‘memoirs', 16),
#  ('dacca', 16),
#  ('1947-1951’', 16),
#  ('inaugural', 16),
#  ("'dhaka", 16),
#  ('held', 16),
#  ('twinge', 16),
#  ('nostalgia', 16),
#  ('walk', 16),
#  ('upper', 16),
#  ('tiers', 16),
#  ('srabonti', 16),
#  ('narmeen', 16),
#  ("ali's", 16),
#  ("'broken", 16),
#  ('voices', 16),
#  ('writes', 16),
#  ("'across", 16),
#  ('oceans', 16),
#  ('off', 16),
#  ('beaten', 16),
#  ('track', 16),
#  ('mohammad', 16),
#  ('rafiq’s', 16),
#  ('collection', 16),
#  ('carolyn', 16),
#  ('b', 16),
#  ('brown’s', 16),
#  ('presents', 16),
#  ('shaheed', 16),
#  ('quaderi', 16),
#  ('anglophone', 16),
#  ('readers', 16),
#  ('blue', 16),
#  ('venom', 16),
#  ('forbidden', 16),
#  ('incense', 16),
#  ('shamsul', 16),
#  ("haq's", 16),
#  ('two', 16),
#  ('linguistic', 16),
#  ('examination', 16),
#  ('azizul', 16),
#  ("huq's", 16),
#  ('tales', 16),
#  ('untold', 16),
#  ('agony', 16),
#  ('imdadul', 16),
#  ("milan's", 16),
#  ('"two', 16),
#  ('written', 16),
#  ('rizia', 16),
#  ("rahman's", 16),
#  ('"letters', 16),
#  ('appalling', 16),
#  ('reality', 16),
#  ('versus', 16),
#  ('magical', 16),
#  ('resolution', 16),
#  ('manzoorul', 16),
#  ('islam’s', 16),
#  ('‘absurd', 16),
#  ('night’', 16),
#  ('shaheen', 16),
#  ('akhtar’s', 16),
#  ('‘beloved', 16),
#  ('rongomala’', 16),
#  ('complex', 16),
#  ('tale', 16),
#  ('love', 16),
#  ('gender', 16),
#  ('class', 16),
#  ('touch', 16),
#  ('soul', 16),
#  ('painted', 16),
#  ('pictures', 16),
#  ('words', 16),
#  ('heart', 16),
#  ('nausheen', 16),
#  ("eusuf's", 16),
#  ('elegy', 16),
#  ('eros', 16),
#  ('ged', 16),
#  ('service', 16),
#  ('support', 15),
#  ('professor', 15),
#  ('links', 15),
#  ('centers', 15),
#  ('</div', 15),
#  ('holiday', 14),
#  ('ashura', 14),
#  ('6', 14),
#  ('4', 14),
#  ('7', 14),
#  ('01', 14),
#  ('condolence', 14),
#  ('fairuz', 14),
#  ('saalim', 14),
#  ('bba', 14),
#  ('(batch', 14),
#  ('221', 14),
#  ('died', 14),
#  ('29', 14),
#  ('3', 14),
#  ('celebrating', 14),
#  ('yoga', 14),
#  ('day', 14),
#  ('26', 14),
#  ('নবীন', 14),
#  ('বরণ', 14),
#  ('প্রবন্ধ', 14),
#  ('গান', 14),
#  ('আবৃত্তি', 14),
#  ('প্রতিযোগিতা', 14),
#  ('22', 14),
#  ('সর্বস্তরে', 14),
#  ('বাংলা', 14),
#  ('ভাষাঃ', 14),
#  ('বানানে', 14),
#  ('উচ্চারণে', 14),
#  ('olympiad', 14),
#  ('newspaper', 14),
#  ('(cls', 14),
#  ('“british', 14),
#  ('council', 14),
#  ('last', 14),
#  ('stanza', 14),
#  ('beautiful', 14),
#  ('poem', 14),
#  ('william', 14),
#  ('“a', 14),
#  ('night', 14),
#  ('thought.”', 14),
#  ('defined', 14),
#  ('spontaneous', 14),
#  ('(ci', 14),
#  ('“eee', 14),
#  ('virtual', 14),
#  ('2021”', 14),
#  ('robotics', 14),
#  ('(uerc', 14),
#  ('performing', 14),
#  ('chitrok', 14),
#  ('gallery', 14),
#  ('along', 14),
#  ('2', 14),
#  ('nd', 14),
#  ('january', 14),
#  ('marifa', 14),
#  ('khan', 14),
#  ('(211013012', 14),
#  ('fatema', 14),
#  ('aftab', 14),
#  ('miah', 14),
#  ('(211013016', 14),
#  ('juhi', 14),
#  ('rubaba', 14),
#  ('jurana', 14),
#  ('(201013070', 14),
#  ('online', 13),
#  ('download', 13),
#  ('cse', 13),
#  ('morning', 13),
#  ('tribute', 13),
#  ('adventure', 13),
#  ('debating', 13),
#  ('wellness', 13),
#  ('shangskriti', 13),
#  ('shangshad', 13),
#  ('welfare', 13),
#  ('theatre', 13),
#  ('yes', 13),
#  ('association', 13),
#  ('services', 12),
#  ('advising', 12),
#  ('essential', 12),
#  ('affairs', 12),
#  ("registrar's", 12),
#  ('objectives', 12),
#  ('undertake', 12),
#  ('publication', 12),
#  ("bangladesh's", 12),
#  ('(cbs', 12),
#  ('advance', 12),
#  ('facilitate', 12),
#  ('methods', 12),
#  ('first', 12),
#  ('university-based', 12),
#  ('conducting', 12),
#  ('entrepreneurship', 12),
#  ('towards', 12),
#  ('ethical', 12),
#  ('environmental', 12),
#  ('sustainability', 12),
#  ('cetl', 12),
#  ('full', 12),
#  ('fledged', 12),
#  ('established', 12),
#  ('primarily', 12),
#  ('implementing', 12),
#  ('staff', 12),
#  ('asian', 12),
#  ('c-sas', 12),
#  ('orient', 12),
#  ('regional', 12),
#  ('secure', 12),
#  ('positive', 12),
#  ('futures', 12),
#  ('asia', 12),
#  ('institute', 12),
#  ('solely', 12),
#  ('(dtc', 12),
#  ('celebrates', 12),
#  ('rich', 12),
#  ('tradition', 12),
#  ('encouraging', 12),
#  ('contemporary', 12),
#  ('literature', 12),
#  ("center's", 12),
#  ('primary', 12),
#  ('generate', 12),
#  ('scholarly', 12),
#  ('training', 12),
#  ('broad', 12),
#  ('ambit', 12),
#  ('renowned', 12),
#  ('edupreneur', 12),
#  ('many', 12),
#  ('corporate', 12),
#  ('institution-building', 12),
#  ('pro', 12),
#  ('capable', 12),
#  ('academician', 12),
#  ('recognized', 12),
#  ('specialist', 12),
#  ('conservation', 12),
#  ('climate', 12),
#  ('(cas', 12),
#  ('archaeologist', 12),
#  ('twenty-five', 12),
#  ('years’', 12),
#  ('archaeology', 12),
#  ('hamidul', 12),
#  ('leading', 12),
#  ('award-winning', 12),
#  ('special', 12),
#  ('(bot', 12),
#  ('reputed', 12),
#  ('over', 12),
#  ('27', 12),
#  ('author', 12),
#  ('successful', 12),
#  ('prominent', 12),
#  ('thinker', 12),
#  ('regular', 12),
#  ('dailies', 12),
#  ('ghani', 12),
#  ('experienced', 12),
#  ('journalism', 12),
#  ('esteemed', 12),
#  ('pioneer', 12),
#  ('literacy', 12),
#  ('challenging', 12),
#  ('know', 12),
#  ('tourism', 12),
#  ('status', 12),
#  ('instill', 12),
#  ('professional', 12),
#  ('talks/seminars', 12),
#  ('works', 12),
#  ('such', 12),
#  ('alpana', 12),
#  ('21', 12),
#  ('february', 12),
#  ('pohela', 12),
#  ('boishakh', 12),
#  ('exhibitions', 12),
#  ('and/or', 12),
#  ('premises', 12),
#  ('inter-university', 12),
#  ('exhibitions/competitions', 12),
#  ('invite', 12),
#  ('famous', 12),
#  ('artists', 12),
#  ('professionals', 12),
#  ('guidance', 12),
#  ('related', 12),
#  ('studying', 12),
#  ('grooming', 12),
#  ('doing', 12),
#  ('it-savvy', 12),
#  ('hopes', 12),
#  ('technologies', 12),
#  ('share', 12),
#  ('benefited', 12),
#  ('comsoc', 12),
#  ('keen', 12),
#  ('intellectual', 12),
#  ('capacity', 12),
#  ('gather', 12),
#  ('civilization', 12),
#  ('views', 12),
#  ('collective', 12),
#  ('levels', 12),
#  ('modes', 12),
#  ('public', 12),
#  ('speaking', 12),
#  ('dialogues', 12),
#  ('debates', 12),
#  ('formats', 12),
#  ('train', 12),
#  ('faculties', 12),
#  ('logical', 12),
#  ('reasoning', 12),
#  ('sharpen', 12),
#  ('bring', 12),
#  ('rooms', 12),
#  ('expose', 12),
#  ('awaiting', 12),
#  ('circuit', 12),
#  ('hardware', 12),
#  ('analysis', 12),
#  ('providing', 12),
#  ('concepts', 12),
#  ('something', 12),
#  ('constructive', 12),
#  ('useful', 12),
#  ('conduct', 12),
#  ('lecture', 12),
#  ('series', 12),
#  ('assign', 12),
#  ('cannot', 12),
#  ('possible', 12),
#  ('without', 12),
#  ('teachers', 12),
#  ('ete', 12),
#  ('comprised', 12),
#  ('mainly', 12),
#  ('teams', 12),
#  ('include', 12),
#  ('any', 12),
#  ('per', 12),
#  ('request', 12),
#  ('motivated', 12),
#  ('common', 12),
#  ('desire', 12),
#  ('participate', 12),
#  ('broadly', 12),
#  ('participants', 12),
#  ('existing', 12),
#  ('enjoy', 12),
#  ('recreational', 12),
#  ('fellowship', 12),
#  ('both', 12),
#  ('male', 12),
#  ('female', 12),
#  ('devoted', 12),
#  ('true', 12),
#  ('cinematic', 12),
#  ('premise', 12),
#  ('how', 12),
#  ('sometimes', 12),
#  ('crafts', 12),
#  ('filmmaking', 12),
#  ('exhibit', 12),
#  ('own', 12),
#  ('ufc', 12),
#  ('between/among', 12),
#  ('practitioners', 12),
#  ('scholars', 12),
#  ('coordinate', 12),
#  ('state', 12),
#  ('tennis', 12),
#  ('carom', 12),
#  ('ludo', 12),
#  ('chess', 12),
#  ('checkers', 12),
#  ('gaming', 12),
#  ('basketball', 12),
#  ('volleyball', 12),
#  ('badminton', 12),
#  ('uno', 12),
#  ('monopoly', 12),
#  ('skipping', 12),
#  ('etc', 12),
#  ('semester-wise', 12),
#  ('scheduled', 12),
#  ('thus', 12),
#  ('communicate', 12),
#  ('co-operate', 12),
#  ('enrich', 12),
#  ('students’', 12),
#  ('lifelong', 12),
#  ('value', 12),
#  ('interesting', 12),
#  ('natural', 12),
#  ('potential', 12),
#  ('acquiring', 12),
#  ('command', 12),
#  ('fascinating', 12),
#  ('member', 12),
#  ('gets', 12),
#  ('aware', 12),
#  ('involved', 12),
#  ('stimulate', 12),
#  ('spirit', 12),
#  ('cooperation', 12),
#  ('unity', 12),
#  ('others', 12),
#  ('ingenaes', 12),
#  ('illinois', 12),
#  ('urbana-champagne', 12),
#  ('biid', 12),
#  ('built', 12),
#  ('partnership', 12),
#  ('under', 12),
#  ('was', 12),
#  ('so', 12),
#  ('trained', 12),
#  ('deployed', 12),
#  ('volunteer', 12),
#  ('agents', 12),
#  ('segments', 12),
#  ('sharing', 12),
#  ('especially', 12),
#  ('rural', 12),
#  ('areas', 12),
#  ('voluntary', 12),
#  ('engagement', 12),
#  ('most', 12),
#  ('preferred', 12),
#  ('selima', 12),
#  ('quader', 12),
#  ('chowdhury', 12),
#  ('lecturer', 12),
#  ('build', 12),
#  ('strong', 12),
#  ('team', 12),
#  ('experiment', 12),
#  ('techniques', 12),
#  ('create', 12),
#  ('issues', 12),
#  ('recognition', 12),
#  ('nationally', 12),
#  ('(usdc', 12),
#  ('diverse', 12),
#  ('interests', 12),
#  ('balanced', 12),
#  ('achievable', 12),
#  ('solutions', 12),
#  ('facing', 12),
#  ('see', 12),
#  ('interconnected', 12),
#  ('nature', 12),
#  ('‘sustainability', 12),
#  ('challenge’', 12),
#  ('central', 12),
#  ('work', 12),
#  ('attempt—through', 12),
#  ('trips', 12),
#  ('ongoing', 12),
#  ('working', 12),
#  ('groups—to', 12),
#  ('connections', 12),
#  ('economic', 12),
#  ('prosperity', 12),
#  ('justice', 12),
#  ('movement', 12),
#  ('against', 12),
#  ('corruption', 12),
#  ('exploration', 12),
#  ('across', 12),
#  ('genres', 12),
#  ('mediums', 12),
#  ('expression', 12),
#  ('branches', 12),
#  ('men', 12),
#  ('assist', 12),
#  ('address', 12),
#  ('needs', 12),
#  ('relations', 12),
#  ('people', 12),
#  ('worldwide', 12),
#  ('framework', 12),
#  ('friendship', 12),
#  ('(un', 12),
#  ('politics', 12),
#  ('diplomacy', 12),
#  ('conferences', 12),
#  ('citizen', 12),
#  ('since', 12),
#  ('inception', 12),
#  ('14th', 12),
#  ('club(udmc', 12),
#  ('long', 12),
#  ('way', 12),
#  ('despite', 12),
#  ('adversities', 12),
#  ('extreme', 12),
#  ('pandemic', 12),
#  ('udmc', 12),
#  ('recruits', 12),
#  ('every', 12),
#  ('semester', 12),
#  ('consistently', 12),
#  ('comes', 12),
#  ('inspire', 12),
#  ('knack', 12),
#  ('revered', 12),
#  ('tech', 12),
#  ('icons', 12),
#  ('have', 12),
#  ('lent', 12),
#  ('time', 12),
#  ('insight', 12),
#  ('into', 12),
#  ('perceive', 12),
#  ('essence', 12),
#  ('liberation', 12),
#  ('war', 12),
#  ('accountable', 12),
#  ('citizens', 12),
#  ('initiative', 12),
#  ('(ces', 12),
#  ('student-led', 12),
#  ('promoting', 12),
#  ('diversity', 12),
#  ('fostering', 12),
#  ('inclusivity', 12),
#  ('breaking', 12),
#  ('barriers', 12),
#  ('within', 12),
#  ('community', 12),
#  ('now', 11),
#  ('ranked', 11),
#  ('second', 11),
#  ('spending', 11),
#  ('report', 11),
#  ('us', 10),
#  ("bachelor's", 10),
#  ("master's", 10),
#  ('degrees', 10),
#  ('four', 10),
#  ('here', 10),
#  ('requirements', 10),
#  ('featured', 10),
#  ('extracurricular', 10),
#  ('<div', 10),
#  ('board', 9),
#  ('contact', 9),
#  ('+88-02-223328001-5', 8),
#  ('press', 7),
#  ('login', 7),
#  ('search', 7),
#  ('phone', 7),
#  ('fax', 7),
#  ('+88-02-223328006', 7),
#  ('menu', 6),
#  ('688', 6),
#  ('beribadh', 6),
#  ('roadmohammadpurdhaka', 6),
#  ('1207', 6),
#  ...]

# %% [markdown]
# **5. For inspecting Broken links inside a webpage**
#
# We want to retrieve the response code 200 if the site is fully functional. We'll get the 404 response code if it's not available.

# %%
# Importing libraries
from bs4 import BeautifulSoup, SoupStrainer
import requests

# Getting URL from user
url = input("Enter your url: ")

def broken_page():
  # For making request to get the URL
  user_req_page = requests.get(url)

  # For getting the response code of given URL
  response_code = str(user_req_page.status_code)

  # For displaying the text of the URL in str
  data =user_req_page.text

  # For using BeautifulSoup to access the built-in methods
  soup = BeautifulSoup(data)

  # Iterate over all links on the given URL with the response code next to it i.e 404 for PAGE NOT FOUND, 200 if website is functional/available
  for link in soup.find_all('a'):
    print(f"Url: {link.get('href')} " + f"| Status Code: {response_code}")


#----- NOTE ------#
# --------- TO VERIFY PAGE NOT FOUND 404 ERROR, enter below web link as a input URL --------#
#https://roine.github.com/p1

#------------- Main ---------------#
if __name__ == '__main__':
  broken_page()
# Out:
# Enter your url: https://ulab.edu.bd/
# Url: #main-content | Status Code: 200
# Url: /students | Status Code: 200
# Url: /staff | Status Code: 200
# Url: /research-0 | Status Code: 200
# Url: /about-us | Status Code: 200
# Url: /about-us/about-ulab | Status Code: 200
# Url: /about-us/leadership-governance | Status Code: 200
# Url: http://admissions.ulab.edu.bd | Status Code: 200
# Url: https://admissions.ulab.edu.bd/undergraduate-programs | Status Code: 200
# Url: https://admissions.ulab.edu.bd/graduate-programs | Status Code: 200
# Url: https://admissions.ulab.edu.bd/international-admissions | Status Code: 200
# Url: /academics | Status Code: 200
# Url: /academics/degrees-offered | Status Code: 200
# Url: https://registrar.ulab.edu.bd/academic-calendar-6 | Status Code: 200
# Url: /academics/faculty-list | Status Code: 200
# Url: https://ged.ulab.edu.bd | Status Code: 200
# Url: https://usb.ulab.edu.bd | Status Code: 200
# Url: https://msj.ulab.edu.bd | Status Code: 200
# Url: https://deh.ulab.edu.bd | Status Code: 200
# Url: https://cse.ulab.edu.bd | Status Code: 200
# Url: https://eee.ulab.edu.bd | Status Code: 200
# Url: https://bbs.ulab.edu.bd | Status Code: 200
# Url: https://ulab.edu.bd | Status Code: 200
# Url: https://ofr.ulab.edu.bd | Status Code: 200
# Url: /research-centers | Status Code: 200
# Url: https://ulab.edu.bd | Status Code: 200
# Url: /journals | Status Code: 200
# Url: https://ulab-press.ulab.edu.bd | Status Code: 200
# Url: https://ulab.edu.bd | Status Code: 200
# Url: https://URMS.ulab.edu.bd | Status Code: 200
# Url: https://moodle.ulab.edu.bd/ | Status Code: 200
# Url: https://blendedlearning.ulab.edu.bd | Status Code: 200
# Url: https://ulab.edu.bd/user | Status Code: 200
# Url: https://cocurricular.ulab.edu.bd | Status Code: 200
# Url: /my-ulab/student-support-services | Status Code: 200
# Url: /my-ulab/sports | Status Code: 200
# Url: https://ulab.edu.bd | Status Code: 200
# Url: /administration/vice-chancellor-office | Status Code: 200
# Url: https://registrar.ulab.edu.bd | Status Code: 200
# Url: https://communications.ulab.edu.bd | Status Code: 200
# Url: /staff/directory-administration | Status Code: 200
# Url: https://hr.ulab.edu.bd | Status Code: 200
# Url: https://ito.ulab.edu.bd | Status Code: 200
# Url: /administration/proctors-office | Status Code: 200
# Url: https://oia.ulab.edu.bd | Status Code: 200
# Url: /administration/accounts-office | Status Code: 200
# Url: https://iqac.ulab.edu.bd | Status Code: 200
# Url: /ulab-committees | Status Code: 200
# Url: https://library.ulab.edu.bd | Status Code: 200
# Url: /tribute-national-professor-rafiqul-islam | Status Code: 200
# Url: https://convocation.ulab.edu.bd | Status Code: 200
# Url: /contact-us | Status Code: 200
# Url: https://ulab.edu.bd | Status Code: 200
# Url: /students | Status Code: 200
# Url: /staff | Status Code: 200
# Url: /research-0 | Status Code: 200
# Url: /academics | Status Code: 200
# Url: http://oia.ulab.edu.bd/partnership | Status Code: 200
# Url: http://admissions.ulab.edu.bd/ | Status Code: 200
# Url: https://oam.ulab.edu.bd/ | Status Code: 200
# Url: https://www.facebook.com/ULABian | Status Code: 200
# Url: https://twitter.com/ULABian | Status Code: 200
# Url: https://www.instagram.com/ulab.official | Status Code: 200
# Url: https://www.youtube.com/c/ULABian | Status Code: 200
# Url: javascript:void(0); | Status Code: 200
# Url: javascript:void(0); | Status Code: 200
# Url: https://ulab.edu.bd | Status Code: 200
# Url: https://oam.ulab.edu.bd/ | Status Code: 200
# Url: javascript:void(0); | Status Code: 200
# Url: javascript:void(0); | Status Code: 200
# Url: https://admissions.ulab.edu.bd/ | Status Code: 200
# Url: None | Status Code: 200
# Url: None | Status Code: 200
# Url: /node/2016 | Status Code: 200
# Url: /node/2017 | Status Code: 200
# Url: https://oam.ulab.edu.bd/ | Status Code: 200
# Url: /advising | Status Code: 200
# Url: /essential-skills | Status Code: 200
# Url: https://library.ulab.edu.bd/ | Status Code: 200
# Url: https://sao.ulab.edu.bd/ | Status Code: 200
# Url: https://registrar.ulab.edu.bd/ | Status Code: 200
# Url: http://admissions.ulab.edu.bd/prospectus | Status Code: 200
# Url: None | Status Code: 200
# Url: javascript:void(0); | Status Code: 200
# Url: javascript:void(0); | Status Code: 200
# Url: javascript:void(0); | Status Code: 200
# Url: javascript:void(0); | Status Code: 200
# Url: None | Status Code: 200
# Url: /schools#school-deh | Status Code: 200
# Url: /schools#school-usb | Status Code: 200
# Url: /schools#school-cse | Status Code: 200
# Url: /schools#school-msj | Status Code: 200
# Url: None | Status Code: 200
# Url: 2025/07/02/holiday-ashura-2025 | Status Code: 200
# Url: 2025/07/02/midterm-exam-summer-2025-graduate | Status Code: 200
# Url: 2025/07/02/midterm-exam-summer-2025-undergraduate | Status Code: 200
# Url: 2025/07/01/condolence-notice-fairuz-saalim-bba-batch-221 | Status Code: 200
# Url: /notice-board | Status Code: 200
# Url: event/celebrating-international-yoga-day-2025 | Status Code: 200
# Url: event/celebrating-international-yoga-day-2025 | Status Code: 200
# Url: event/rabindra-nazrul-anniversary-and-freshers-orientation-summer-2025 | Status Code: 200
# Url: event/rabindra-nazrul-anniversary-and-freshers-orientation-summer-2025 | Status Code: 200
# Url: event/সর্বস্তরে-বাংলা-ভাষাঃ-শুদ্ধ-বানানে-শুদ্ধ-উচ্চারণে | Status Code: 200
# Url: event/সর্বস্তরে-বাংলা-ভাষাঃ-শুদ্ধ-বানানে-শুদ্ধ-উচ্চারণে | Status Code: 200
# Url: /node/1194 | Status Code: 200
# Url: None | Status Code: 200
# Url: /sites/default/files/ULABian-English-Spring-Summer-2023.pdf | Status Code: 200
# Url: /sites/default/files/ULABian-Bangla-Spring-Summer-2023.pdf | Status Code: 200
# Url: https://ulab.edu.bd/2023/08/28/eee-olympiad-summer-2023-organized-eee-department-ulab | Status Code: 200
# Url: https://msj.ulab.edu.bd/bss/ulabian-a-campus-newspaper/ulabian-issues | Status Code: 200
# Url: http://cls.ulab.edu.bd/2019/09/02/center-language-studies-cls-organized-a-poster-presentation-competition | Status Code: 200
# Url: https://ulab.edu.bd/2020/11/01/poetry-or-prose | Status Code: 200
# Url: https://deh.ulab.edu.bd/deh-curriculum-integration-ci-project | Status Code: 200
# Url: http://eee.ulab.edu.bd/2021/05/27/eee-virtual-project-showcasing-spring-2021-organized-dept-eee-ulab-and-ulab | Status Code: 200
# Url: https://msj.ulab.edu.bd/every-semester-msj-department-launches-exhibit-facilitate-curriculum-integration | Status Code: 200
# Url: http://cse.ulab.edu.bd/2020/01/07/department-cse-and-ulab-computer-society-organized-a-project-showcasing-fall-2019 | Status Code: 200
# Url: https://msj.ulab.edu.bd/bss/ulabian-a-campus-newspaper/ulabian-issues | Status Code: 200
# Url: https://deh.ulab.edu.bd/studentprojects/themorningcriticbymarifakhan | Status Code: 200
# Url: https://deh.ulab.edu.bd/studentprojects/theliterarytributefatemaaftabmiah | Status Code: 200
# Url: https://deh.ulab.edu.bd/studentprojects/thecriticbyjuhirubabajuranajahan | Status Code: 200
# Url: https://ulab.edu.bd/2023/04/18/project-showcasing-and-poster-presentation-spring-2023-organized-ulab-eee-department | Status Code: 200
# Url: https://msj.ulab.edu.bd/bss/ulabian-a-campus-newspaper/ulabian-issues | Status Code: 200
# Url: None | Status Code: 200
# Url: /node/1858 | Status Code: 200
# Url: http://cat.ulab.edu.bd/ | Status Code: 200
# Url: http://cas.ulab.edu.bd/ | Status Code: 200
# Url: http://cbs.ulab.edu.bd/ | Status Code: 200
# Url: http://cqs.ulab.edu.bd/ | Status Code: 200
# Url: http://ces.ulab.edu.bd/ | Status Code: 200
# Url: http://cetl.ulab.edu.bd/ | Status Code: 200
# Url: http://cls.ulab.edu.bd/ | Status Code: 200
# Url: https://csas.ulab.edu.bd | Status Code: 200
# Url: http://csd.ulab.edu.bd/ | Status Code: 200
# Url: http://dtc.ulab.edu.bd/ | Status Code: 200
# Url: http://chpd.ulab.edu.bd/ | Status Code: 200
# Url: None | Status Code: 200
# Url: https://usb.ulab.edu.bd/faculty/prof-imran-rahman | Status Code: 200
# Url: https://ulab.edu.bd/faculty/prof-jude-wr-genilo-phd | Status Code: 200
# Url: https://ulab.edu.bd/faculty/dr-samiya-selim | Status Code: 200
# Url: https://cas.ulab.edu.bd/faculty/prof-shahnaj-husne-jahan-phd | Status Code: 200
# Url: https://ulab.edu.bd/faculty/prof-kaiser-hamidul-haq-phd | Status Code: 200
# Url: https://ulab.edu.bd/faculty/professor-shamsad-mortuza-phd | Status Code: 200
# Url: https://ulab.edu.bd/faculty/prof-abdul-mannan | Status Code: 200
# Url: https://ulab.edu.bd/faculty/arifa-ghani-rahman | Status Code: 200
# Url: https://msj.ulab.edu.bd/faculty/din-m-sumon-rahman-phd | Status Code: 200
# Url: None | Status Code: 200
# Url: #news-tab | Status Code: 200
# Url: #in-media-tab | Status Code: 200
# Url: 2025/06/29/events-took-place-rabindra-nazrul-anniversary-and-freshers-orientation-summer-2025 | Status Code: 200
# Url: 2025/06/29/“-only-ray-hope-you”-ulab’s-msj-forum-unpacks-aftermath-revolution | Status Code: 200
# Url: 2025/06/20/msj-department-ulab-holds-orientation-summer-2025 | Status Code: 200
# Url: 2025/06/03/distinguished-webinar-next-gen-energy-efficient-electronics-3d-integration-and-smart | Status Code: 200
# Url: 2025/06/03/ulab-signs-mou-venturas-ltd-boost-career-opportunities-japan | Status Code: 200
# Url: 2025/05/21/eee-study-tour-raozan-thermal-power-station-and-kaptai-hydro-power-station | Status Code: 200
# Url: 2025/05/20/md-sajid-hasan-selected-reviewer-international-conference-artificial-intelligence | Status Code: 200
# Url: 2025/04/29/curriculum-integration-exhibition-wraps-shilpakala-academy-focus-network-propaganda | Status Code: 200
# Url: 2025/04/27/eee-project-and-poster-exhibition-2025 | Status Code: 200
# Url: 2025/04/24/workshop-participation-march-2025 | Status Code: 200
# Url: 2025/04/21/poster-presentation-and-seminar-heritage-preservation | Status Code: 200
# Url: 2025/04/08/international-conference-participation-–-april-2025 | Status Code: 200
# Url: 2025/03/26/deans-list-scholarship-fall-2024 | Status Code: 200
# Url: 2025/03/26/vice-chancellor-honors-scholarship-student-list-fall-2024 | Status Code: 200
# Url: 2025/03/24/ulab-eee-undergraduate-publishes-ieee-paper-solar-pv-system-national-stadium | Status Code: 200
# Url: 2025/03/13/round-table-discussion-power-women-uprising-greater-political-participation | Status Code: 200
# Url: 2025/03/06/named-scholarship-fall-2024 | Status Code: 200
# Url: 2025/03/02/seminar-quantum-spin-hall-insulators | Status Code: 200
# Url: 2025/02/19/building-a-un-engineering-career | Status Code: 200
# Url: 2025/01/30/best-capstone-project-awards-–-spring-2025 | Status Code: 200
# Url: /news | Status Code: 200
# Url: ulab-ces-and-dhaka-tribune-host-‘national-civil-society-dialog-reforming-university-education | Status Code: 200
# Url: life-modern-dhaka-portrayed-a-strange-coincidence-and-other-stories | Status Code: 200
# Url: ‘bangladesh-stories’-gives-inside-look-country’s-garment-industry | Status Code: 200
# Url: book-review-devils-thumbprint | Status Code: 200
# Url: upon-rereading-‘forty-steps’ | Status Code: 200
# Url: interleaving-personal-memory-political-history-review-‘memoirs-dacca-university-1947-1951’ | Status Code: 200
# Url: inaugural-dhaka-dialogue-held-ulab | Status Code: 200
# Url: a-twinge-nostalgia | Status Code: 200
# Url: a-walk-through-upper-tiers-society-review-srabonti-narmeen-alis-novel-broken-voices | Status Code: 200
# Url: a-poet-lives-she-writes-a-review-across-oceans | Status Code: 200
# Url: beaten-track-review-mohammad-rafiq’s-poetry-collection-carolyn-b-brown’s-translation | Status Code: 200
# Url: kaiser-haq-presents-shaheed-quaderi-anglophone-readers | Status Code: 200
# Url: blue-venom-and-forbidden-incense-review-syed-shamsul-haqs-two-novellas | Status Code: 200
# Url: a-linguistic-examination-twelve-stories-review-hasan-azizul-huqs-twelve-stories | Status Code: 200
# Url: tales-untold-agony-a-review-imdadul-haq-milans-two-novellas | Status Code: 200
# Url: their-lives-written-blood-review-rizia-rahmans-letters-blood-a-novel | Status Code: 200
# Url: appalling-reality-versus-magical-resolution-a-review-syed-manzoorul-islam’s-‘absurd-night’ | Status Code: 200
# Url: review-shaheen-akhtar’s-‘beloved-rongomala’-a-complex-tale-love-gender-and-class | Status Code: 200
# Url: a-touch-soul-through-painted-pictures | Status Code: 200
# Url: not-a-review-words-heart-nausheen-eusufs-not-elegy-eros | Status Code: 200
# Url: /media | Status Code: 200
# Url: None | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-1 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-2 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-3 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-4 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-5 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-6 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-7 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-8 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-9 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-10 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-11 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-12 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-13 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-14 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-15 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-16 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-17 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-18 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-19 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-20 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-21 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-22 | Status Code: 200
# Url: #res-724b7e34f98fdc51d1b4d40cd67a9fe3-23 | Status Code: 200
# Url: /ulab-adventure-club | Status Code: 200
# Url: /ulab-art-club | Status Code: 200
# Url: /ulab-business-club | Status Code: 200
# Url: /ulab-computer-society | Status Code: 200
# Url: /ulab-debating-club | Status Code: 200
# Url: /ulab-electronics-club | Status Code: 200
# Url: /ulab-field-sports-club | Status Code: 200
# Url: /ulab-film-club | Status Code: 200
# Url: /ulab-indoor-games-club | Status Code: 200
# Url: /ulab-language-club | Status Code: 200
# Url: /ulab-media-club | Status Code: 200
# Url: /ulab-nutrition-and-wellness-club | Status Code: 200
# Url: /ulab-shangskriti-shangshad | Status Code: 200
# Url: /ulab-social-welfare-club | Status Code: 200
# Url: /theatre-ulab | Status Code: 200
# Url: /ulab-sustainable-development-club | Status Code: 200
# Url: /ulab-yes-club | Status Code: 200
# Url: /ulab-literary-society | Status Code: 200
# Url: /ulab-rotaract-club | Status Code: 200
# Url: /ulab-model-united-nations-association | Status Code: 200
# Url: /ulab-digital-marketing-club | Status Code: 200
# Url: /ulab-1971-history-club | Status Code: 200
# Url: https://cocurricular.ulab.edu.bd/ulab-kaleidoscope-club | Status Code: 200
# Url: # | Status Code: 200
# Url: tel:+8802223328001 | Status Code: 200
# Url: https://www.facebook.com/ULABian | Status Code: 200
# Url: https://twitter.com/ULABian | Status Code: 200
# Url: https://www.instagram.com/ulab.official | Status Code: 200
# Url: https://www.youtube.com/c/ULABian | Status Code: 200
# Url: https://ulab.edu.bd/programs | Status Code: 200
# Url: https://ofr.ulab.edu.bd/ | Status Code: 200
# Url: https://pub.ulab.edu.bd | Status Code: 200
# Url: https://ulab.edu.bd/research-centers | Status Code: 200
# Url: /where-is-ulab | Status Code: 200
# Url: https://admissions.ulab.edu.bd/undergraduate-programs | Status Code: 200
# Url: https://admissions.ulab.edu.bd/graduate-programs | Status Code: 200
# Url: https://admissions.ulab.edu.bd/international-admissions | Status Code: 200
# Url: https://admissions.ulab.edu.bd/scholarships-aid | Status Code: 200
# Url: https://admissions.ulab.edu.bd/prospectus/ | Status Code: 200
# Url: https://admissions.ulab.edu.bd/payment-guideline | Status Code: 200
# Url: /giving | Status Code: 200
# Url: https://alumni.ulab.edu.bd/ | Status Code: 200
# Url: https://hr.ulab.edu.bd/jobs-at-ulab | Status Code: 200
# Url: https://urms.ulab.edu.bd/ | Status Code: 200
# Url: https://library.ulab.edu.bd | Status Code: 200
# Url: https://registrar.ulab.edu.bd/academic-calendar-6 | Status Code: 200
# Url: https://ulab-press.ulab.edu.bd | Status Code: 200
# Url: https://ged.ulab.edu.bd | Status Code: 200
# Url: /contact-us | Status Code: 200
# Url: https://iqac.ulab.edu.bd/ | Status Code: 200
# Url: https://mail.ulab.edu.bd | Status Code: 200
# Url: https://moodle.ulab.edu.bd/ | Status Code: 200
# Url: https://sites.google.com/ulab.edu.bd/ulabfilecabinet/ | Status Code: 200
# Url: https://ulab.edu.bd/shuttle-service-schedule | Status Code: 200
# Url: /annual-reports | Status Code: 200
# Url: /tender-invitation-leasing-cafeteria | Status Code: 200

# %% [markdown]
# **6. For getting the source code of the webpage**
#
# Here, we will be using 'page_source' method is used retrieve the page source of the webpage the user is currently accessing.
#
# *NOTE: (Page source : The source code/page source is the programming behind any webpage)*

# %%
# install chromium, its driver, and selenium
# !apt update
# !apt install chromium-chromedriver
# !pip install selenium

# set options to be headless, ..
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,758 kB]
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,103 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,569 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,420 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,266 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,102 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4,963 kB]
# Fetched 26.6 MB in 5s (4,892 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 41 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   apparmor chromium-browser libfuse3-3 libudev1 snapd squashfs-tools
#   systemd-hwe-hwdb udev
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils fuse3 zenity | kdialog
# The following NEW packages will be installed:
#   apparmor chromium-browser chromium-chromedriver libfuse3-3 snapd
#   squashfs-tools systemd-hwe-hwdb udev
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 8 newly installed, 0 to remove and 40 not upgraded.
# Need to get 30.3 MB of archives.
# After this operation, 123 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 apparmor amd64 3.0.4-2ubuntu2.4 [598 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 squashfs-tools amd64 1:4.5-3build1 [159 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev1 amd64 249.11-0ubuntu3.16 [76.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 udev amd64 249.11-0ubuntu3.16 [1,557 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfuse3-3 amd64 3.10.5-1build1 [81.2 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 snapd amd64 2.67.1+22.04 [27.8 MB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 chromium-browser amd64 1:85.0.4183.83-0ubuntu2.22.04.1 [49.2 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 chromium-chromedriver amd64 1:85.0.4183.83-0ubuntu2.22.04.1 [2,308 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 systemd-hwe-hwdb all 249.11.5 [3,228 B]
# Fetched 30.3 MB in 4s (7,271 kB/s)
# Preconfiguring packages ...
# Selecting previously unselected package apparmor.
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../apparmor_3.0.4-2ubuntu2.4_amd64.deb ...
# Unpacking apparmor (3.0.4-2ubuntu2.4) ...
# Selecting previously unselected package squashfs-tools.
# Preparing to unpack .../squashfs-tools_1%3a4.5-3build1_amd64.deb ...
# Unpacking squashfs-tools (1:4.5-3build1) ...
# Preparing to unpack .../libudev1_249.11-0ubuntu3.16_amd64.deb ...
# Unpacking libudev1:amd64 (249.11-0ubuntu3.16) over (249.11-0ubuntu3.12) ...
# Setting up libudev1:amd64 (249.11-0ubuntu3.16) ...
# Selecting previously unselected package udev.
# (Reading database ... 126481 files and directories currently installed.)
# Preparing to unpack .../udev_249.11-0ubuntu3.16_amd64.deb ...
# Unpacking udev (249.11-0ubuntu3.16) ...
# Selecting previously unselected package libfuse3-3:amd64.
# Preparing to unpack .../libfuse3-3_3.10.5-1build1_amd64.deb ...
# Unpacking libfuse3-3:amd64 (3.10.5-1build1) ...
# Selecting previously unselected package snapd.
# Preparing to unpack .../snapd_2.67.1+22.04_amd64.deb ...
# Unpacking snapd (2.67.1+22.04) ...
# Setting up apparmor (3.0.4-2ubuntu2.4) ...
# Created symlink /etc/systemd/system/sysinit.target.wants/apparmor.service → /lib/systemd/system/apparmor.service.
# Setting up squashfs-tools (1:4.5-3build1) ...
# Setting up udev (249.11-0ubuntu3.16) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libfuse3-3:amd64 (3.10.5-1build1) ...
# Setting up snapd (2.67.1+22.04) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.apparmor.service → /lib/systemd/system/snapd.apparmor.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.autoimport.service → /lib/systemd/system/snapd.autoimport.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.core-fixup.service → /lib/systemd/system/snapd.core-fixup.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.recovery-chooser-trigger.service → /lib/systemd/system/snapd.recovery-chooser-trigger.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.seeded.service → /lib/systemd/system/snapd.seeded.service.
# Created symlink /etc/systemd/system/cloud-final.service.wants/snapd.seeded.service → /lib/systemd/system/snapd.seeded.service.
# Unit /lib/systemd/system/snapd.seeded.service is added as a dependency to a non-existent unit cloud-final.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.service → /lib/systemd/system/snapd.service.
# Created symlink /etc/systemd/system/timers.target.wants/snapd.snap-repair.timer → /lib/systemd/system/snapd.snap-repair.timer.
# Created symlink /etc/systemd/system/sockets.target.wants/snapd.socket → /lib/systemd/system/snapd.socket.
# Created symlink /etc/systemd/system/final.target.wants/snapd.system-shutdown.service → /lib/systemd/system/snapd.system-shutdown.service.
# Selecting previously unselected package chromium-browser.
# (Reading database ... 126710 files and directories currently installed.)
# Preparing to unpack .../chromium-browser_1%3a85.0.4183.83-0ubuntu2.22.04.1_amd64.deb ...
# => Installing the chromium snap
# ==> Checking connectivity with the snap store
# ===> System doesn't have a working snapd, skipping
# Unpacking chromium-browser (1:85.0.4183.83-0ubuntu2.22.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_1%3a85.0.4183.83-0ubuntu2.22.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (1:85.0.4183.83-0ubuntu2.22.04.1) ...
# Selecting previously unselected package systemd-hwe-hwdb.
# Preparing to unpack .../systemd-hwe-hwdb_249.11.5_all.deb ...
# Unpacking systemd-hwe-hwdb (249.11.5) ...
# Setting up systemd-hwe-hwdb (249.11.5) ...
# Setting up chromium-browser (1:85.0.4183.83-0ubuntu2.22.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (1:85.0.4183.83-0ubuntu2.22.04.1) ...
# Processing triggers for udev (249.11-0ubuntu3.16) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...
# Collecting selenium
#   Downloading selenium-4.34.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting urllib3~=2.5.0 (from urllib3[socks]~=2.5.0->selenium)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting trio~=0.30.0 (from selenium)
#   Downloading trio-0.30.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2025.6.15 in /usr/local/lib/python3.11/dist-packages (from selenium) (2025.7.9)
# Requirement already satisfied: typing_extensions~=4.14.0 in /usr/local/lib/python3.11/dist-packages (from selenium) (4.14.1)
# Requirement already satisfied: websocket-client~=1.8.0 in /usr/local/lib/python3.11/dist-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (3.10)
# Collecting outcome (from trio~=0.30.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (1.3.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.12.2->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]~=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.16.0)
# Downloading selenium-4.34.2-py3-none-any.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 14.5 MB/s eta 0:00:00
# Downloading trio-0.30.0-py3-none-any.whl (499 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.2/499.2 kB 31.1 MB/s eta 0:00:00
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.8/129.8 kB 10.6 MB/s eta 0:00:00
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, urllib3, outcome, trio, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.4.0
#     Uninstalling urllib3-2.4.0:
#       Successfully uninstalled urllib3-2.4.0
# Successfully installed outcome-1.3.0.post0 selenium-4.34.2 trio-0.30.0 trio-websocket-0.12.2 urllib3-2.5.0 wsproto-1.2.0

# %%
#------------- FOR DISPLAYING SOURCE CODE OF THE WEBPAGE -------------#

# open it, go to a website, and get results
wd = webdriver.Chrome(options=options)

# Prompt user to enter the URL
url = input("Enter your url: ")

# For making request to get the URL
wd.get(url)

# To display code results
print(wd.page_source)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-10-60379162.py in <cell line: 0>()
#       2
#       3 # open it, go to a website, and get results
# ----> 4 wd = webdriver.Chrome(options=options)
#       5
#       6 # Prompt user to enter the URL
#
# NameError: name 'webdriver' is not defined

# %% [markdown]
# **7. Extraction of all URLs from a website without duplication**

# %%
#---- Importing libraries ----#
import re
import requests
from bs4 import BeautifulSoup

all_links = set() #------ Creating a unique set of links ------#

for i in range(7):
   r = requests.get(("https://ulab.edu.bd/?page={}").format(i))
   soup = BeautifulSoup(r.content , "html.parser")
   for link in soup.find_all("a",href=re.compile('/')):
            link = (link.get('href'))
            #----- For the removal of duplicate URLs, We will simply add a link to that set; this assures that it's distinct ------#
            if link not in all_links:
              print(link)
            all_links.add(link)
# Out:
# /students
# /staff
# /research-0
# /about-us
# /about-us/about-ulab
# /about-us/leadership-governance
# http://admissions.ulab.edu.bd
# https://admissions.ulab.edu.bd/undergraduate-programs
# https://admissions.ulab.edu.bd/graduate-programs
# https://admissions.ulab.edu.bd/international-admissions
# /academics
# /academics/degrees-offered
# https://registrar.ulab.edu.bd/academic-calendar-6
# /academics/faculty-list
# https://ged.ulab.edu.bd
# https://usb.ulab.edu.bd
# https://msj.ulab.edu.bd
# https://deh.ulab.edu.bd
# https://cse.ulab.edu.bd
# https://eee.ulab.edu.bd
# https://bbs.ulab.edu.bd
# https://ulab.edu.bd
# https://ofr.ulab.edu.bd
# /research-centers
# /journals
# https://ulab-press.ulab.edu.bd
# https://URMS.ulab.edu.bd
# https://moodle.ulab.edu.bd/
# https://blendedlearning.ulab.edu.bd
# https://ulab.edu.bd/user
# https://cocurricular.ulab.edu.bd
# /my-ulab/student-support-services
# /my-ulab/sports
# /administration/vice-chancellor-office
# https://registrar.ulab.edu.bd
# https://communications.ulab.edu.bd
# /staff/directory-administration
# https://hr.ulab.edu.bd
# https://ito.ulab.edu.bd
# /administration/proctors-office
# https://oia.ulab.edu.bd
# /administration/accounts-office
# https://iqac.ulab.edu.bd
# /ulab-committees
# https://library.ulab.edu.bd
# /tribute-national-professor-rafiqul-islam
# https://convocation.ulab.edu.bd
# /contact-us
# http://oia.ulab.edu.bd/partnership
# http://admissions.ulab.edu.bd/
# https://oam.ulab.edu.bd/
# https://www.facebook.com/ULABian
# https://twitter.com/ULABian
# https://www.instagram.com/ulab.official
# https://www.youtube.com/c/ULABian
# https://admissions.ulab.edu.bd/
# /node/2016
# /node/2017
# /advising
# /essential-skills
# https://library.ulab.edu.bd/
# https://sao.ulab.edu.bd/
# https://registrar.ulab.edu.bd/
# http://admissions.ulab.edu.bd/prospectus
# /schools#school-deh
# /schools#school-usb
# /schools#school-cse
# /schools#school-msj
# 2025/07/02/holiday-ashura-2025
# 2025/07/02/midterm-exam-summer-2025-graduate
# 2025/07/02/midterm-exam-summer-2025-undergraduate
# 2025/07/01/condolence-notice-fairuz-saalim-bba-batch-221
# /notice-board
# event/celebrating-international-yoga-day-2025
# event/rabindra-nazrul-anniversary-and-freshers-orientation-summer-2025
# event/সর্বস্তরে-বাংলা-ভাষাঃ-শুদ্ধ-বানানে-শুদ্ধ-উচ্চারণে
# /node/1194
# /sites/default/files/ULABian-English-Spring-Summer-2023.pdf
# /sites/default/files/ULABian-Bangla-Spring-Summer-2023.pdf
# https://ulab.edu.bd/2023/08/28/eee-olympiad-summer-2023-organized-eee-department-ulab
# https://msj.ulab.edu.bd/bss/ulabian-a-campus-newspaper/ulabian-issues
# http://cls.ulab.edu.bd/2019/09/02/center-language-studies-cls-organized-a-poster-presentation-competition
# https://ulab.edu.bd/2020/11/01/poetry-or-prose
# https://deh.ulab.edu.bd/deh-curriculum-integration-ci-project
# http://eee.ulab.edu.bd/2021/05/27/eee-virtual-project-showcasing-spring-2021-organized-dept-eee-ulab-and-ulab
# https://msj.ulab.edu.bd/every-semester-msj-department-launches-exhibit-facilitate-curriculum-integration
# http://cse.ulab.edu.bd/2020/01/07/department-cse-and-ulab-computer-society-organized-a-project-showcasing-fall-2019
# https://deh.ulab.edu.bd/studentprojects/themorningcriticbymarifakhan
# https://deh.ulab.edu.bd/studentprojects/theliterarytributefatemaaftabmiah
# https://deh.ulab.edu.bd/studentprojects/thecriticbyjuhirubabajuranajahan
# https://ulab.edu.bd/2023/04/18/project-showcasing-and-poster-presentation-spring-2023-organized-ulab-eee-department
# /node/1858
# http://cat.ulab.edu.bd/
# http://cas.ulab.edu.bd/
# http://cbs.ulab.edu.bd/
# http://cqs.ulab.edu.bd/
# http://ces.ulab.edu.bd/
# http://cetl.ulab.edu.bd/
# http://cls.ulab.edu.bd/
# https://csas.ulab.edu.bd
# http://csd.ulab.edu.bd/
# http://dtc.ulab.edu.bd/
# http://chpd.ulab.edu.bd/
# https://usb.ulab.edu.bd/faculty/prof-imran-rahman
# https://ulab.edu.bd/faculty/prof-jude-wr-genilo-phd
# https://ulab.edu.bd/faculty/dr-samiya-selim
# https://cas.ulab.edu.bd/faculty/prof-shahnaj-husne-jahan-phd
# https://ulab.edu.bd/faculty/prof-kaiser-hamidul-haq-phd
# https://ulab.edu.bd/faculty/professor-shamsad-mortuza-phd
# https://ulab.edu.bd/faculty/prof-abdul-mannan
# https://ulab.edu.bd/faculty/arifa-ghani-rahman
# https://msj.ulab.edu.bd/faculty/din-m-sumon-rahman-phd
# 2025/06/29/events-took-place-rabindra-nazrul-anniversary-and-freshers-orientation-summer-2025
# 2025/06/29/“-only-ray-hope-you”-ulab’s-msj-forum-unpacks-aftermath-revolution
# 2025/06/20/msj-department-ulab-holds-orientation-summer-2025
# 2025/06/03/distinguished-webinar-next-gen-energy-efficient-electronics-3d-integration-and-smart
# 2025/06/03/ulab-signs-mou-venturas-ltd-boost-career-opportunities-japan
# 2025/05/21/eee-study-tour-raozan-thermal-power-station-and-kaptai-hydro-power-station
# 2025/05/20/md-sajid-hasan-selected-reviewer-international-conference-artificial-intelligence
# 2025/04/29/curriculum-integration-exhibition-wraps-shilpakala-academy-focus-network-propaganda
# 2025/04/27/eee-project-and-poster-exhibition-2025
# 2025/04/24/workshop-participation-march-2025
# 2025/04/21/poster-presentation-and-seminar-heritage-preservation
# 2025/04/08/international-conference-participation-–-april-2025
# 2025/03/26/deans-list-scholarship-fall-2024
# 2025/03/26/vice-chancellor-honors-scholarship-student-list-fall-2024
# 2025/03/24/ulab-eee-undergraduate-publishes-ieee-paper-solar-pv-system-national-stadium
# 2025/03/13/round-table-discussion-power-women-uprising-greater-political-participation
# 2025/03/06/named-scholarship-fall-2024
# 2025/03/02/seminar-quantum-spin-hall-insulators
# 2025/02/19/building-a-un-engineering-career
# 2025/01/30/best-capstone-project-awards-–-spring-2025
# /news
# /media
# /ulab-adventure-club
# /ulab-art-club
# /ulab-business-club
# /ulab-computer-society
# /ulab-debating-club
# /ulab-electronics-club
# /ulab-field-sports-club
# /ulab-film-club
# /ulab-indoor-games-club
# /ulab-language-club
# /ulab-media-club
# /ulab-nutrition-and-wellness-club
# /ulab-shangskriti-shangshad
# /ulab-social-welfare-club
# /theatre-ulab
# /ulab-sustainable-development-club
# /ulab-yes-club
# /ulab-literary-society
# /ulab-rotaract-club
# /ulab-model-united-nations-association
# /ulab-digital-marketing-club
# /ulab-1971-history-club
# https://cocurricular.ulab.edu.bd/ulab-kaleidoscope-club
# https://ulab.edu.bd/programs
# https://ofr.ulab.edu.bd/
# https://pub.ulab.edu.bd
# https://ulab.edu.bd/research-centers
# /where-is-ulab
# https://admissions.ulab.edu.bd/scholarships-aid
# https://admissions.ulab.edu.bd/prospectus/
# https://admissions.ulab.edu.bd/payment-guideline
# /giving
# https://alumni.ulab.edu.bd/
# https://hr.ulab.edu.bd/jobs-at-ulab
# https://urms.ulab.edu.bd/
# https://iqac.ulab.edu.bd/
# https://mail.ulab.edu.bd
# https://sites.google.com/ulab.edu.bd/ulabfilecabinet/
# https://ulab.edu.bd/shuttle-service-schedule
# /annual-reports
# /tender-invitation-leasing-cafeteria

# %% [markdown]
# **8. Measuring the forntend and backend performance of website**

# %%
#----- Installation of selenium and chromedriver in google colab -----#
# !pip install selenium
# !apt-get update
# !apt install chromium-chromedriver
# Out:
# Requirement already satisfied: selenium in /usr/local/lib/python3.11/dist-packages (4.34.2)
# Requirement already satisfied: urllib3~=2.5.0 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]~=2.5.0->selenium) (2.5.0)
# Requirement already satisfied: trio~=0.30.0 in /usr/local/lib/python3.11/dist-packages (from selenium) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in /usr/local/lib/python3.11/dist-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.6.15 in /usr/local/lib/python3.11/dist-packages (from selenium) (2025.7.9)
# Requirement already satisfied: typing_extensions~=4.14.0 in /usr/local/lib/python3.11/dist-packages (from selenium) (4.14.1)
# Requirement already satisfied: websocket-client~=1.8.0 in /usr/local/lib/python3.11/dist-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (3.10)
# Requirement already satisfied: outcome in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.11/dist-packages (from trio-websocket~=0.12.2->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]~=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.16.0)
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# chromium-chromedriver is already the newest version (1:85.0.4183.83-0ubuntu2.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.

# %%
#---- Importing libraries ----#
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import csv
import os.path

# %%
#---- Accessing chromedriver in google colab ----#
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
wd = webdriver.Chrome(options=options)
driver =webdriver.Chrome(options=options)

# %%
#----- Creating csv file to write the calculated performance of the website
csv_path = "performance.csv"
file = open(csv_path, 'w', newline='')
writer = csv.writer(file)
writer.writerow(["backendPerformance_calc","frontendPerformance_calc"])


#----- Getting input for webiste from user
url = input("Enter url :")
print("This is the website link that you entered:", url)

#----- Setting iterations for testing the perfromance
iterations = 10
for i in range(iterations):
    driver =webdriver.Chrome(options=options)
    driver.get(url) #-- Passing url as parameter in Selenium method (driver.get)

    #-- Using Navigation Timing API to calculate the timings, Here driver.execute_script is called and the return value is stored in navigationStart
    #driver.execute_script then synchronously executes JavaScript in the current window or frame. In this case the ‘return window.performance.timing.navigationStart’ code will run.
    navigationStart = driver.execute_script("return window.performance.timing.navigationStart")
    responseStart = driver.execute_script("return window.performance.timing.responseStart")
    domComplete = driver.execute_script("return window.performance.timing.domComplete")

    backendPerformance_calc = responseStart - navigationStart
    frontendPerformance_calc = domComplete - responseStart

    #--This will print iteration wise backend and front end performance for website
    print("Iteration no:", i)
    print("Back End performance in MS: %s" % backendPerformance_calc)
    print("Front End performance in MS: %s" % frontendPerformance_calc)
    print("------------------------")

    #-- Writing row wise data in the file
    writer.writerow([backendPerformance_calc,frontendPerformance_calc])
    driver.close()
# Out:
# Enter url :https://ulab.edu.bd/
# This is the website link that you entered: https://ulab.edu.bd/
# Iteration no: 0
# Back End performance in MS: 612
# Front End performance in MS: 8012
# ------------------------
# Iteration no: 1
# Back End performance in MS: 583
# Front End performance in MS: 3343
# ------------------------
# Iteration no: 2
# Back End performance in MS: 586
# Front End performance in MS: 3913
# ------------------------
# Iteration no: 3
# Back End performance in MS: 565
# Front End performance in MS: 6683
# ------------------------
# Iteration no: 4
# Back End performance in MS: 680
# Front End performance in MS: 4354
# ------------------------
# Iteration no: 5
# Back End performance in MS: 602
# Front End performance in MS: 3249
# ------------------------
# Iteration no: 6
# Back End performance in MS: 598
# Front End performance in MS: 7496
# ------------------------
# Iteration no: 7
# Back End performance in MS: 618
# Front End performance in MS: 4218
# ------------------------
# Iteration no: 8
# Back End performance in MS: 579
# Front End performance in MS: 7571
# ------------------------
# Iteration no: 9
# Back End performance in MS: 593
# Front End performance in MS: 6589
# ------------------------

# %%
#---- For closing the CSV file and the WebDriver ----#
driver.quit()
file.close()

# %%
#---- To view performance in a dataframe ----#
import pandas as pd
df=pd.read_csv("performance.csv")

# %%
#----- Displaying DataFrames output ------#
df
# Out:
#    backendPerformance_calc  frontendPerformance_calc
# 0                      612                      8012
# 1                      583                      3343
# 2                      586                      3913
# 3                      565                      6683
# 4                      680                      4354
# 5                      602                      3249
# 6                      598                      7496
# 7                      618                      4218
# 8                      579                      7571
# 9                      593                      6589
